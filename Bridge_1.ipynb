# %% [markdown]
# # Python bridge 1

# %% [markdown]
# * introduction to numpy
# * basic oo concepts in python
# * practice making functions and simple classes
# * homework: ???

# %%
import numpy as np

# %%
x_vals = np.arange(0,30,step=np.pi/16)
y_vals = np.sin(x_vals)
data = np.vstack([x_vals, y_vals])

# %%
# object type

print(type(data))
print(type(test))

# data type (how it's stored in memory)

# with numpy we can call:
print(data.dtype)

# also:
# integers, complex, string, boolean etc
# Out:
# <class 'numpy.ndarray'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8685afd88aca> in <module>
#       2
#       3 print(type(data))
# ----> 4 print(type(test))
#       5
#       6 # data type (how it's stored in memory)
#
# NameError: name 'test' is not defined

# %%
np.random.rand(100, 1)
# Out:
# array([[0.80686535],
#        [0.30328787],
#        [0.13306068],
#        [0.15469299],
#        [0.41084397],
#        [0.71247185],
#        [0.56453821],
#        [0.55491044],
#        [0.52682772],
#        [0.7833095 ],
#        [0.25496814],
#        [0.61563354],
#        [0.54095577],
#        [0.63078542],
#        [0.66919827],
#        [0.82111056],
#        [0.73312421],
#        [0.05824746],
#        [0.24362309],
#        [0.61493779],
#        [0.25579933],
#        [0.36036643],
#        [0.3672504 ],
#        [0.98426743],
#        [0.98179395],
#        [0.48488024],
#        [0.88648762],
#        [0.25874002],
#        [0.53595738],
#        [0.99383515],
#        [0.85149674],
#        [0.37716698],
#        [0.09421315],
#        [0.00225724],
#        [0.19833786],
#        [0.26411833],
#        [0.35035939],
#        [0.63688029],
#        [0.48747792],
#        [0.48902147],
#        [0.07615082],
#        [0.87341296],
#        [0.8589914 ],
#        [0.97751873],
#        [0.63202915],
#        [0.2332867 ],
#        [0.35355492],
#        [0.29642355],
#        [0.53799797],
#        [0.11766891],
#        [0.68011513],
#        [0.75248858],
#        [0.51997779],
#        [0.70004539],
#        [0.49633709],
#        [0.53260078],
#        [0.24468013],
#        [0.17914335],
#        [0.97682458],
#        [0.88164015],
#        [0.69026642],
#        [0.73613493],
#        [0.13768865],
#        [0.29315657],
#        [0.3503788 ],
#        [0.29477309],
#        [0.00845866],
#        [0.08561759],
#        [0.01904269],
#        [0.65759727],
#        [0.30803654],
#        [0.80436397],
#        [0.17651593],
#        [0.80002403],
#        [0.48775053],
#        [0.55694455],
#        [0.97664935],
#        [0.77963941],
#        [0.08755005],
#        [0.90332655],
#        [0.03421569],
#        [0.83040626],
#        [0.96864773],
#        [0.54112564],
#        [0.46829994],
#        [0.44682505],
#        [0.46559824],
#        [0.36870776],
#        [0.54537901],
#        [0.00504563],
#        [0.816448  ],
#        [0.02564671],
#        [0.41792965],
#        [0.48748151],
#        [0.92002292],
#        [0.91391835],
#        [0.38709622],
#        [0.5381809 ],
#        [0.39986345],
#        [0.67790489]])

# %%
np.random.randn(100, 1)
# Out:
# array([[-1.58420427],
#        [-0.76629332],
#        [-0.0644615 ],
#        [ 0.88991891],
#        [-0.10433141],
#        [ 0.18487157],
#        [-0.24278505],
#        [ 0.8794294 ],
#        [-0.40480024],
#        [-0.85780344],
#        [ 0.30740613],
#        [ 0.0231382 ],
#        [-1.16536909],
#        [-0.71124196],
#        [-0.10178581],
#        [-0.52250639],
#        [ 1.18034906],
#        [-1.08299902],
#        [-1.40752803],
#        [ 0.94697262],
#        [-0.07097913],
#        [ 0.50362712],
#        [ 1.33084443],
#        [ 0.48433515],
#        [ 0.25572598],
#        [-1.39613864],
#        [ 1.16382679],
#        [-0.53796989],
#        [-0.38351483],
#        [ 0.50894806],
#        [ 2.03089117],
#        [-1.40936462],
#        [-1.79005372],
#        [ 1.13858506],
#        [ 0.3934622 ],
#        [ 0.39725946],
#        [-1.31820388],
#        [-1.26622257],
#        [-1.35176058],
#        [-0.90446045],
#        [ 0.30605255],
#        [-1.382709  ],
#        [ 1.07552728],
#        [ 0.93405072],
#        [ 0.98696315],
#        [ 0.39831158],
#        [-0.5266384 ],
#        [-0.4488668 ],
#        [ 1.27818961],
#        [ 1.78861098],
#        [ 1.08498981],
#        [ 0.89346683],
#        [-2.6670012 ],
#        [ 0.51776344],
#        [ 0.30138198],
#        [-0.94318382],
#        [-1.74289577],
#        [-0.55830473],
#        [ 0.61754021],
#        [-0.01882879],
#        [-0.44037216],
#        [ 0.08679493],
#        [ 1.22671866],
#        [-1.69640353],
#        [ 0.67147106],
#        [ 0.90842433],
#        [ 0.49468132],
#        [ 0.87081403],
#        [ 0.0776152 ],
#        [-1.27950685],
#        [-1.22016308],
#        [-0.79698619],
#        [-0.2102677 ],
#        [-2.075923  ],
#        [ 3.0760361 ],
#        [-0.64933886],
#        [ 0.62542701],
#        [ 0.53076105],
#        [-0.8953915 ],
#        [-1.85559487],
#        [ 0.23229551],
#        [-0.77435978],
#        [-0.14684254],
#        [-0.82325621],
#        [ 0.74486559],
#        [ 0.70841313],
#        [ 0.05120546],
#        [-1.49347295],
#        [-0.52620921],
#        [ 0.54058634],
#        [ 0.32263134],
#        [-0.35045397],
#        [ 1.57833957],
#        [ 0.97455924],
#        [-1.69935183],
#        [ 0.12603657],
#        [-0.97900743],
#        [-1.94178199],
#        [ 0.09239496],
#        [ 0.14987407]])
